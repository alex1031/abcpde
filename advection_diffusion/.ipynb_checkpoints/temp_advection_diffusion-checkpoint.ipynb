# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from scipy.special import erfcinv as erfcinv
plt.rcParams['animation.html'] = 'html5'

# %% [markdown]
# # Implementation from Video (2D Advection Diffusion)

# %%
nx = 51
ny = 51
Lx = 1.0
Ly = 1.0
x = np.linspace(0, Lx, nx)
y = np.linspace(0, Ly, ny)
# dxy=100
# x = np.mgrid[-2500:2500+dxy:dxy]
# y = x
dx = Lx/(nx-1)
dy = Ly/(ny-1)
xx, yy = np.meshgrid(x, y)

# %%
ω0 = 2.0*np.pi
# ω0 = -np.pi
u0 = lambda x, y: np.sin(ω0*x) * np.sin(ω0*y)
# u0 = lambda x, y: 1/np.sqrt(2*np.pi) * np.exp(-1/2 * (x-0.5)**2) * 1/np.sqrt(2*np.pi) * np.exp(-1/2 * (y-0.5)**2)
# plotting the initial conditions
plt.contourf(xx, yy, u0(xx, yy))

# %%
cx = 1.0
cy = 0.0

dt = 0.001
tend = 2.0
t = 0

cflx = cx * dt/dx
cfly = cy * dt/dy

# setup initial condition
sol = []
u = np.zeros([nx+2, ny+2])
u[1:-1, 1:-1] = u0(xx, yy)
# set periodic boundaries

u[:,0] = u[:,-3] #x-minus face
u[:,-1] = u[:,2] #x-plus face
u[0,:] = u[-3,:] #y-minus face
u[-1,:] = u[2,:] #y-plus face
sol.append(u)

# %%
while t < tend:
    un = sol[-1]
    unew = un.copy()
    unew[1:-1, 1:-1] = un[1:-1, 1:-1] - cflx * (un[1:-1, 1:-1] - un[1:-1, :-2]) - cfly * (un[1:-1, 1:-1] - un[:-2,1:-1])
    unew[:,0] = unew[:,-3] #x-minus face
    unew[:,-1] = unew[:,2] #x-plus face
    unew[0,:] = unew[-3,:] #y-minus face
    unew[-1,:] = unew[2,:] #y-plus face
    unew[-1] = unew[2]
    unew[0] = unew[-3]
    sol.append(unew)
    t += dt

# %%
new_sol = []
for solution in sol:
    new_sol.append(solution[1:-1, 1:-1])

# %%
# plt.imshow(new_sol[0])
# plt.imshow(new_sol[100])
# plt.imshow(new_sol[200])
plt.imshow(new_sol[300])
# plt.imshow(new_sol[-1])

# %% [markdown]
# ## 3-D Advection Diffusion

# %%
import time
import numpy as np
import matplotlib.pyplot as plt

# %%
# --- GRID SETUP ---
nx, ny, nz = 51, 51, 51  # Grid size (x, y, height)
Lx, Ly, Lz = 1.0, 1.0, 0.5  # Domain size (m)
dx, dy, dz = Lx/(nx-1), Ly/(ny-1), Lz/(nz-1)  # Grid spacing

x = np.linspace(0, Lx, nx)
y = np.linspace(0, Ly, ny)
z = np.linspace(0, Lz, nz)
xx, yy, zz = np.meshgrid(x, y, z, indexing='ij')

# --- PHYSICAL PARAMETERS ---
cx, cy, cz = 1, 0, 0.5  # Advection velocities (m/s)
sx, sy, sz = 0.01, 0.01, 0.005  # Diffusion coefficients (m^2/s)
dt = 0.001  # Time step (s)
tend = 2.0  # Total simulation time (s)
t = 0

cfl_x, cfl_y, cfl_z = cx * dt/dx, cy * dt/dy, cz * dt/dz
diff_x, diff_y, diff_z = sx * dt/dx**2, sy * dt/dy**2, sz * dt/dz**2

# --- INITIAL CONDITION (Gaussian Plume) ---
u = np.zeros((nx+2, ny+2, nz+2))

sol = [u.copy()]

source_x, source_y, source_z = nx//2, ny//2, nz//5
Q = 1e-3

# --- TIME INTEGRATION ---
while t < tend:
    un = sol[-1]
    unew = un.copy()

    # Advection (Upwind Scheme)
    unew[1:-1, 1:-1, 1:-1] -= cfl_x * (un[1:-1, 1:-1, 1:-1] - un[1:-1, :-2, 1:-1])
    unew[1:-1, 1:-1, 1:-1] -= cfl_y * (un[1:-1, 1:-1, 1:-1] - un[:-2, 1:-1, 1:-1])
    unew[1:-1, 1:-1, 1:-1] -= cfl_z * (un[1:-1, 1:-1, 1:-1] - un[1:-1, 1:-1, :-2])

    # Diffusion (Central Differencing)
    unew[1:-1, 1:-1, 1:-1] += diff_x * (un[1:-1, 2:, 1:-1] - 2*un[1:-1, 1:-1, 1:-1] + un[1:-1, :-2, 1:-1])
    unew[1:-1, 1:-1, 1:-1] += diff_y * (un[2:, 1:-1, 1:-1] - 2*un[1:-1, 1:-1, 1:-1] + un[:-2, 1:-1, 1:-1])
    unew[1:-1, 1:-1, 1:-1] += diff_z * (un[1:-1, 1:-1, 2:] - 2*un[1:-1, 1:-1, 1:-1] + un[1:-1, 1:-1, :-2])

    unew[source_x, source_y, source_z] += Q * dt

    # Apply periodic boundary conditions
    unew[:, 0, :] = unew[:, -3, :]  # x-minus face
    unew[:, -1, :] = unew[:, 2, :]  # x-plus face
    unew[0, :, :] = unew[-3, :, :]  # y-minus face
    unew[-1, :, :] = unew[2, :, :]  # y-plus face
    unew[:, :, 0] = unew[:, :, -3]  # z-bottom face
    unew[:, :, -1] = unew[:, :, 2]  # z-top face

    sol.append(unew.copy())
    t += dt

# --- VISUALIZATION (Plume at Mid-Height) ---
numerical_C = sol[-1][1:-1, 1:-1, 1:-1]
plan_view_numerical = np.mean(numerical_C, axis=2) # Change this 
X, Y = np.meshgrid(x, y)
plt.figure(figsize=(8,6))
plt.pcolor(X, Y, plan_view_numerical * 1e6, cmap='jet', shading='auto')
plt.colorbar()
plt.xlabel("x (m)")
plt.ylabel("y (m)")
plt.title("Numerical Model: Plan View")
plt.show()

# %% [markdown]
# ## Change in Advection Velocity

# %%
def run_simulation(cx, cy, cz):
    start_time = time.time()
    nx, ny, nz = 51, 51, 51  # Grid size (x, y, height)
    Lx, Ly, Lz = 1.0, 1.0, 0.5 # Domain Size
    dx, dy, dz = Lx/(nx-1), Ly/(ny-1), Lz/(nz-1)
    x = np.linspace(0, Lx, nx)
    y = np.linspace(0, Ly, ny)
    z = np.linspace(0, Lz, nz)
    
    # Physical parameters
    sx, sy, sz = 0.01, 0.01, 0.005

    dt = 0.001
    
    tend = 2.0
    t = 0

    cfl_x, cfl_y, cfl_z = cx * dt/dx, cy * dt/dy, cz * dt/dz
    diff_x, diff_y, diff_z = sx * dt/dx**2, sy * dt/dy**2, sz * dt/dz**2
    
    u = np.zeros((nx+2, ny+2, nz+2))
    sol = [u.copy()]

    source_x, source_y, source_z = nx//2, ny//2, nz//5
    Q = 1e-3
    
    while t < tend:
        un = sol[-1]
        unew = un.copy()

        # Advection (Upwind Scheme)
        unew[1:-1, 1:-1, 1:-1] -= cfl_x * (un[1:-1, 1:-1, 1:-1] - un[1:-1, :-2, 1:-1])
        unew[1:-1, 1:-1, 1:-1] -= cfl_y * (un[1:-1, 1:-1, 1:-1] - un[:-2, 1:-1, 1:-1])
        unew[1:-1, 1:-1, 1:-1] -= cfl_z * (un[1:-1, 1:-1, 1:-1] - un[1:-1, 1:-1, :-2])
    
        # Diffusion (Central Differencing)
        unew[1:-1, 1:-1, 1:-1] += diff_x * (un[1:-1, 2:, 1:-1] - 2*un[1:-1, 1:-1, 1:-1] + un[1:-1, :-2, 1:-1])
        unew[1:-1, 1:-1, 1:-1] += diff_y * (un[2:, 1:-1, 1:-1] - 2*un[1:-1, 1:-1, 1:-1] + un[:-2, 1:-1, 1:-1])
        unew[1:-1, 1:-1, 1:-1] += diff_z * (un[1:-1, 1:-1, 2:] - 2*un[1:-1, 1:-1, 1:-1] + un[1:-1, 1:-1, :-2])

        unew[source_x, source_y, source_z] += Q * dt

        sol.append(unew.copy())
        t += dt
    
    numerical_C = sol[-1][1:-1, 1:-1, 1:-1]
    end_time = time.time()
    print(f"Simulation (Advection Coefficient: {sx}x{sy}x{sz}) took {end_time - start_time:.2f} seconds")
    return np.mean(numerical_C, axis=2), x, y

# %%
c = [(1, 1, 0.5), (3, 3, 0.5), (0, 1, 0.5), (0, 3, 0.5), (1, 0, 0.5), (3, 0, 0.5), (0, 0, 0.5), (0, 0, 1)] 

fig, axes = plt.subplots(4, 2, figsize=(8, 8), sharex=True, sharey=True)
all_data = []

# Run all simulations and store data
for cx, cy, cz in s:
    plan_view, x, y = run_simulation(cx, cy, cz)
    all_data.append(plan_view)

# Determine color scale limits
vmin, vmax = np.min(all_data), np.max(all_data)

X, Y = np.meshgrid(x, y)
for i, (cx, cy, cz) in enumerate(c):
    ax = axes.flatten()[i]
    c = ax.pcolor(X, Y, all_data[i] * 1e6, cmap='jet', shading='auto', vmin=vmin * 1e6, vmax=vmax * 1e6)
    ax.set_title(f'Advection: {cx}x{cy}x{cz}', fontsize=10)
    ax.set_xlabel("x (m)")
    ax.set_ylabel("y (m)")

# Add a single colorbar
cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])  # Adjust position and size
fig.colorbar(c, cax=cbar_ax)

fig.tight_layout(rect=[0, 0, 0.9, 1])  # Prevent overlap
plt.show()
# Out:
# Simulation (Advection Coefficient: 0.01x0.01x0.005) took 15.20 seconds
# Simulation (Advection Coefficient: 0.01x0.01x0.005) took 14.04 seconds
# Simulation (Advection Coefficient: 0.01x0.01x0.005) took 14.20 seconds
# Simulation (Advection Coefficient: 0.01x0.01x0.005) took 14.36 seconds
# Simulation (Advection Coefficient: 0.01x0.01x0.005) took 14.35 seconds
# Simulation (Advection Coefficient: 0.01x0.01x0.005) took 13.99 seconds
# Simulation (Advection Coefficient: 0.01x0.01x0.005) took 14.25 seconds
# Simulation (Advection Coefficient: 0.01x0.01x0.005) took 14.09 seconds
# C:\Users\Adrian D02\AppData\Local\Temp\ipykernel_19564\2281738690.py:26: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(rect=[0, 0, 0.9, 1])  # Prevent overlap

# %% [markdown]
# ## Change in Domain/Grid Spacing

# %%
def run_simulation(nx, ny, nz, Lx, Ly, Lz):
    start_time = time.time()
    dx, dy, dz = Lx/(nx-1), Ly/(ny-1), Lz/(nz-1)
    x = np.linspace(0, Lx, nx)
    y = np.linspace(0, Ly, ny)
    z = np.linspace(0, Lz, nz)
    
    # Physical parameters
    cx, cy, cz = 1, 1, 0.5
    sx, sy, sz = 0.01, 0.01, 0.005

    dt_adv = min(dx/cx, dy/cy, dz/cz)
    dt_diff = min(dx**2/(2*sx), dy**2/(2*sy), dz**2/(2*sz))
    dt = 0.25 * min(dt_adv, dt_diff)
    
    tend = 2.0
    t = 0

    cfl_x, cfl_y, cfl_z = cx * dt/dx, cy * dt/dy, cz * dt/dz
    diff_x, diff_y, diff_z = sx * dt/dx**2, sy * dt/dy**2, sz * dt/dz**2
    
    u = np.zeros((nx+2, ny+2, nz+2))
    sol = [u.copy()]

    source_x, source_y, source_z = nx//2, ny//2, nz//5
    Q = 1e-3
    
    while t < tend:
        un = sol[-1]
        unew = un.copy()

        # Advection (Upwind Scheme)
        unew[1:-1, 1:-1, 1:-1] -= cfl_x * (un[1:-1, 1:-1, 1:-1] - un[1:-1, :-2, 1:-1])
        unew[1:-1, 1:-1, 1:-1] -= cfl_y * (un[1:-1, 1:-1, 1:-1] - un[:-2, 1:-1, 1:-1])
        unew[1:-1, 1:-1, 1:-1] -= cfl_z * (un[1:-1, 1:-1, 1:-1] - un[1:-1, 1:-1, :-2])
    
        # Diffusion (Central Differencing)
        unew[1:-1, 1:-1, 1:-1] += diff_x * (un[1:-1, 2:, 1:-1] - 2*un[1:-1, 1:-1, 1:-1] + un[1:-1, :-2, 1:-1])
        unew[1:-1, 1:-1, 1:-1] += diff_y * (un[2:, 1:-1, 1:-1] - 2*un[1:-1, 1:-1, 1:-1] + un[:-2, 1:-1, 1:-1])
        unew[1:-1, 1:-1, 1:-1] += diff_z * (un[1:-1, 1:-1, 2:] - 2*un[1:-1, 1:-1, 1:-1] + un[1:-1, 1:-1, :-2])

        unew[source_x, source_y, source_z] += Q * dt

        sol.append(unew.copy())
        t += dt
    
    numerical_C = sol[-1][1:-1, 1:-1, 1:-1]
    end_time = time.time()
    print(f"Simulation (Grid: {nx}x{ny}x{nz}, Domain: {Lx}x{Ly}x{Lz}) took {end_time - start_time:.2f} seconds")
    return np.mean(numerical_C, axis=2), x, y

# %%
# Grid and domain configurations
grids = [(21, 21, 21), (51, 51, 51), (101, 101, 101)]
domains = [(1.0, 1.0, 1.0), (2.0, 2.0, 1.0), (4.0, 4.0, 1.0)]

fig, axes = plt.subplots(3, 3, figsize=(12, 12))

for i, (nx, ny, nz) in enumerate(grids):
    for j, (Lx, Ly, Lz) in enumerate(domains):
        plan_view, x, y = run_simulation(nx, ny, nz, Lx, Ly, Lz)
        X, Y = np.meshgrid(x, y)
        ax = axes[i, j]
        c = ax.pcolor(X, Y, plan_view * 1e6, cmap='jet', shading='auto')
        fig.colorbar(c, ax=ax)
        ax.set_title(f'Grid: {nx}x{ny}x{nz}, Domain: {Lx}x{Ly}x{Lz}')
        ax.set_xlabel("x (m)")
        ax.set_ylabel("y (m)")

plt.tight_layout()
plt.show()
# Out:
# Simulation (Grid: 21x21x21, Domain: 1.0x1.0x1.0) took 0.05 seconds
# Simulation (Grid: 21x21x21, Domain: 2.0x2.0x1.0) took 0.03 seconds
# Simulation (Grid: 21x21x21, Domain: 4.0x4.0x1.0) took 0.02 seconds
# Simulation (Grid: 51x51x51, Domain: 1.0x1.0x1.0) took 2.92 seconds
# Simulation (Grid: 51x51x51, Domain: 2.0x2.0x1.0) took 1.40 seconds
# Simulation (Grid: 51x51x51, Domain: 4.0x4.0x1.0) took 1.69 seconds
# Simulation (Grid: 101x101x101, Domain: 1.0x1.0x1.0) took 86.45 seconds
# Simulation (Grid: 101x101x101, Domain: 2.0x2.0x1.0) took 42.58 seconds
# Simulation (Grid: 101x101x101, Domain: 4.0x4.0x1.0) took 41.04 seconds

# %% [markdown]
# ## Testing Different Diffusion Coefficient

# %%
def run_simulation(sx, sy, sz):
    start_time = time.time()
    nx, ny, nz = 51, 51, 51  # Grid size (x, y, height)
    Lx, Ly, Lz = 1.0, 1.0, 0.5 # Domain Size
    dx, dy, dz = Lx/(nx-1), Ly/(ny-1), Lz/(nz-1)
    x = np.linspace(0, Lx, nx)
    y = np.linspace(0, Ly, ny)
    z = np.linspace(0, Lz, nz)
    
    # Physical parameters
    cx, cy, cz = 1, 0, 0.5

    dt = 0.001
    
    tend = 2.0
    t = 0

    cfl_x, cfl_y, cfl_z = cx * dt/dx, cy * dt/dy, cz * dt/dz
    diff_x, diff_y, diff_z = sx * dt/dx**2, sy * dt/dy**2, sz * dt/dz**2
    
    u = np.zeros((nx+2, ny+2, nz+2))
    sol = [u.copy()]

    source_x, source_y, source_z = nx//2, ny//2, nz//5
    Q = 1e-3
    
    while t < tend:
        un = sol[-1]
        unew = un.copy()

        # Advection (Upwind Scheme)
        unew[1:-1, 1:-1, 1:-1] -= cfl_x * (un[1:-1, 1:-1, 1:-1] - un[1:-1, :-2, 1:-1])
        unew[1:-1, 1:-1, 1:-1] -= cfl_y * (un[1:-1, 1:-1, 1:-1] - un[:-2, 1:-1, 1:-1])
        unew[1:-1, 1:-1, 1:-1] -= cfl_z * (un[1:-1, 1:-1, 1:-1] - un[1:-1, 1:-1, :-2])
    
        # Diffusion (Central Differencing)
        unew[1:-1, 1:-1, 1:-1] += diff_x * (un[1:-1, 2:, 1:-1] - 2*un[1:-1, 1:-1, 1:-1] + un[1:-1, :-2, 1:-1])
        unew[1:-1, 1:-1, 1:-1] += diff_y * (un[2:, 1:-1, 1:-1] - 2*un[1:-1, 1:-1, 1:-1] + un[:-2, 1:-1, 1:-1])
        unew[1:-1, 1:-1, 1:-1] += diff_z * (un[1:-1, 1:-1, 2:] - 2*un[1:-1, 1:-1, 1:-1] + un[1:-1, 1:-1, :-2])

        unew[source_x, source_y, source_z] += Q * dt

        sol.append(unew.copy())
        t += dt
    
    numerical_C = sol[-1][1:-1, 1:-1, 1:-1]
    end_time = time.time()
    print(f"Simulation (Diffusion Coefficient: {sx}x{sy}x{sz}) took {end_time - start_time:.2f} seconds")
    return np.mean(numerical_C, axis=2), x, y

# %%
s = [(0.01, 0.01, 0.005), (0.03, 0.03, 0.005), (0, 0.01, 0.005), (0, 0.03, 0.005), (0.01, 0, 0.005), (0.03, 0, 0.005)]

fig, axes = plt.subplots(3, 2, figsize=(8, 8), sharex=True, sharey=True)
all_data = []

# Run all simulations and store data
for sx, sy, sz in s:
    plan_view, x, y = run_simulation(sx, sy, sz)
    all_data.append(plan_view)

# Determine color scale limits
vmin, vmax = np.min(all_data), np.max(all_data)

X, Y = np.meshgrid(x, y)
for i, (sx, sy, sz) in enumerate(s):
    ax = axes.flatten()[i]
    c = ax.pcolor(X, Y, all_data[i] * 1e6, cmap='jet', shading='auto', vmin=vmin * 1e6, vmax=vmax * 1e6)
    ax.set_title(f'Diffusion: {sx}x{sy}x{sz}')
    ax.set_xlabel("x (m)")
    ax.set_ylabel("y (m)")

# Add a single colorbar
cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])  # Adjust position and size
fig.colorbar(c, cax=cbar_ax)

fig.tight_layout(rect=[0, 0, 0.9, 1])  # Prevent overlap
plt.show()
# Out:
# Simulation (Diffusion Coefficient: 0.01x0.01x0.005) took 14.09 seconds
# Simulation (Diffusion Coefficient: 0.03x0.03x0.005) took 14.22 seconds
# Simulation (Diffusion Coefficient: 0x0.01x0.005) took 13.92 seconds
# Simulation (Diffusion Coefficient: 0x0.03x0.005) took 13.97 seconds
# Simulation (Diffusion Coefficient: 0.01x0x0.005) took 13.94 seconds
# Simulation (Diffusion Coefficient: 0.03x0x0.005) took 13.78 seconds
# C:\Users\Adrian D02\AppData\Local\Temp\ipykernel_19564\1608718693.py:26: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(rect=[0, 0, 0.9, 1])  # Prevent overlap

# %% [markdown]
# # Trying to Match Gaussian Plume Practical

# %%
def run_simulation(nx, ny, nz, Lx, Ly, Lz, cx, cy, cz, sx, sy, sz):
    start_time = time.time()
    dx, dy, dz = Lx/(nx-1), Ly/(ny-1), Lz/(nz-1)
    x = np.linspace(-2500, 2500, nx)  # Centered at (0,0)
    y = np.linspace(-2500, 2500, ny)
    z = np.linspace(0, Lz, nz)
    
    dt = 1
    
    tend = 1200
    t = 0

    cfl_x, cfl_y, cfl_z = cx * dt/dx, cy * dt/dy, cz * dt/dz
    diff_x, diff_y, diff_z = sx * dt/dx**2, sy * dt/dy**2, sz * dt/dz**2
    
    u = np.zeros((nx+2, ny+2, nz+2))
    sol = [u.copy()]

    source_x, source_y, source_z = nx//2, ny//2, nz//5
    Q = 1e-6
    
    while t < tend:
        un = sol[-1]
        unew = un.copy()

        # Advection (Upwind Scheme)
        unew[1:-1, 1:-1, 1:-1] -= cfl_x * (un[1:-1, 1:-1, 1:-1] - un[1:-1, :-2, 1:-1])
        unew[1:-1, 1:-1, 1:-1] -= cfl_y * (un[1:-1, 1:-1, 1:-1] - un[:-2, 1:-1, 1:-1])
        unew[1:-1, 1:-1, 1:-1] -= cfl_z * (un[1:-1, 1:-1, 1:-1] - un[1:-1, 1:-1, :-2])
    
        # Diffusion (Central Differencing)
        unew[1:-1, 1:-1, 1:-1] += diff_x * (un[1:-1, 2:, 1:-1] - 2*un[1:-1, 1:-1, 1:-1] + un[1:-1, :-2, 1:-1])
        unew[1:-1, 1:-1, 1:-1] += diff_y * (un[2:, 1:-1, 1:-1] - 2*un[1:-1, 1:-1, 1:-1] + un[:-2, 1:-1, 1:-1])
        unew[1:-1, 1:-1, 1:-1] += diff_z * (un[1:-1, 1:-1, 2:] - 2*un[1:-1, 1:-1, 1:-1] + un[1:-1, 1:-1, :-2])

        unew[source_x, source_y, source_z] += Q * dt

        # Added more source points (a center rectangle)
        unew[source_x+1, source_y+1, source_z] += Q * dt
        unew[source_x-1, source_y-1, source_z] += Q * dt
        unew[source_x-1, source_y+1, source_z] += Q * dt
        unew[source_x+1, source_y-1, source_z] += Q * dt
        unew[source_x+1, source_y, source_z] += Q * dt
        unew[source_x-1, source_y, source_z] += Q * dt
        unew[source_x, source_y+1, source_z] += Q * dt
        unew[source_x, source_y-1, source_z] += Q * dt

        sol.append(unew.copy())
        t += dt
    
    numerical_C = sol[-1][1:-1, 1:-1, 1:-1]
    end_time = time.time()
    print(f"Simulation took {end_time - start_time:.2f} seconds")
    return np.mean(numerical_C, axis=2), x, y

# %%
nx, ny, nz = 51, 51, 51  # Grid points
Lx, Ly, Lz = 5000, 5000, 500  # Domain size in meters
cx, cy, cz = 0, 2, 1
sx, sy, sz = 2, 2, 0.5

plan_view, x, y = run_simulation(nx, ny, nz, Lx, Ly, Lz, cx, cy, cz, sx, sy, sz)
X, Y = np.meshgrid(x, y)
plt.figure(figsize=(8,6))
plt.pcolor(X, Y, plan_view * 1e6, cmap='jet', shading='auto')
plt.colorbar()
plt.xlabel("x (m)")
plt.ylabel("y (m)")
plt.title("Plan View")
plt.show()
# Out:
# Simulation took 7.63 seconds

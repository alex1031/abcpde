# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import dataframe_image as dfi

# %%
df = pd.read_csv("dataframe/all_summary_statistics.csv")

# %%
df.head()
# Out:
#                 model quantile param summary_statistic  \
# 0  n0.25_no_smoothing       5%     a              Mean
# 1  n0.25_no_smoothing       5%     a            Median
# 2  n0.25_no_smoothing       5%     a             StDev
# 3  n0.25_no_smoothing       5%     a       Lower Bound
# 4  n0.25_no_smoothing       5%     a       Upper Bound
#
#    Cramer-von Mises Distance  Energy Distance  Kullback-Leibler Divergence  \
# 0                   0.372448         1.084063                     1.763882
# 1                   0.368722         0.993652                     1.636175
# 2                   1.213928         0.726098                     1.095380
# 3                  -1.277052         0.087351                    -0.184579
# 4                   1.664937         2.667740                     3.817911
#
#    Maximum Mean Discrepancy  Wasserstein Distance
# 0                  1.937702              0.442505
# 1                  1.793402              0.346365
# 2                  1.300305              0.586529
# 3                  0.145893             -0.702244
# 4                  4.275075              1.638634

# %%
median = df[(df["summary_statistic"] == "Median") & (df["quantile"] == "0.1%")].reset_index(drop=True)

# %%
median
# Out:
#                    model quantile param summary_statistic  \
# 0     n0.25_no_smoothing     0.1%     a            Median
# 1     n0.25_no_smoothing     0.1%     b            Median
# 2        n0.25_smoothing     0.1%     a            Median
# 3        n0.25_smoothing     0.1%     b            Median
# 4      n0.5_no_smoothing     0.1%     a            Median
# 5      n0.5_no_smoothing     0.1%     b            Median
# 6         n0.5_smoothing     0.1%     a            Median
# 7         n0.5_smoothing     0.1%     b            Median
# 8     n0.75_no_smoothing     0.1%     a            Median
# 9     n0.75_no_smoothing     0.1%     b            Median
# 10       n0.75_smoothing     0.1%     a            Median
# 11       n0.75_smoothing     0.1%     b            Median
# 12       n0_no_smoothing     0.1%     a            Median
# 13       n0_no_smoothing     0.1%     b            Median
# 14  nlinear_no_smoothing     0.1%     a            Median
# 15  nlinear_no_smoothing     0.1%     b            Median
# 16     nlinear_smoothing     0.1%     a            Median
# 17     nlinear_smoothing     0.1%     b            Median
#
#     Cramer-von Mises Distance  Energy Distance  Kullback-Leibler Divergence  \
# 0                    0.317941         0.924164                     0.877295
# 1                    2.873718         0.939164                     0.854490
# 2                    0.613641         0.910284                     0.749632
# 3                    1.562822         1.060764                     0.973748
# 4                    0.278493         1.060542                     1.031221
# 5                    3.028060         0.999107                     0.873227
# 6                    0.606495         0.965110                     0.852159
# 7                    2.601247         1.068184                     1.161319
# 8                    0.330620         1.007980                     1.175377
# 9                    3.735673         0.875226                     0.866145
# 10                   0.621965         0.957763                     9.760249
# 11                   1.528475         1.165928                    -5.333135
# 12                   0.420432         0.928897                     0.994548
# 13                   3.165271         0.960640                     1.308664
# 14                   0.161350         1.624714                     1.423622
# 15                   4.059528         0.596546                     0.394443
# 16                   0.135934         1.405202                     1.237990
# 17                   3.564104         0.772049                     0.551758
#
#     Maximum Mean Discrepancy  Wasserstein Distance
# 0                   0.923422              0.917275
# 1                   0.931151              0.949392
# 2                   0.897766              0.862380
# 3                   1.049428              1.074803
# 4                   1.063073              1.031428
# 5                   0.937027              1.006394
# 6                   0.958787              0.921750
# 7                   1.062278              1.076712
# 8                   1.083785              1.011055
# 9                   0.848655              0.894523
# 10                  0.941576              0.916855
# 11                  1.149321              1.219629
# 12                  0.917605              0.910704
# 13                  0.943380              0.971136
# 14                  1.854787              1.577404
# 15                  0.341353              0.602048
# 16                  1.480608              1.378130
# 17                  0.658955              0.787157

# %%
keep_cols = ["model", "param", "Cramer-von Mises Distance", "Energy Distance", "Kullback-Leibler Divergence",
            "Maximum Mean Discrepancy", "Wasserstein Distance"]

median_table = median[keep_cols]

# %% [markdown]
# # Option 1 -Column for True Value

# %%
option1 = median_table.copy()
option1["True Value"] = np.ones(len(median_table))
option1
# Out:
#                    model param  Cramer-von Mises Distance  Energy Distance  \
# 0     n0.25_no_smoothing     a                   0.317941         0.924164
# 1     n0.25_no_smoothing     b                   2.873718         0.939164
# 2        n0.25_smoothing     a                   0.613641         0.910284
# 3        n0.25_smoothing     b                   1.562822         1.060764
# 4      n0.5_no_smoothing     a                   0.278493         1.060542
# 5      n0.5_no_smoothing     b                   3.028060         0.999107
# 6         n0.5_smoothing     a                   0.606495         0.965110
# 7         n0.5_smoothing     b                   2.601247         1.068184
# 8     n0.75_no_smoothing     a                   0.330620         1.007980
# 9     n0.75_no_smoothing     b                   3.735673         0.875226
# 10       n0.75_smoothing     a                   0.621965         0.957763
# 11       n0.75_smoothing     b                   1.528475         1.165928
# 12       n0_no_smoothing     a                   0.420432         0.928897
# 13       n0_no_smoothing     b                   3.165271         0.960640
# 14  nlinear_no_smoothing     a                   0.161350         1.624714
# 15  nlinear_no_smoothing     b                   4.059528         0.596546
# 16     nlinear_smoothing     a                   0.135934         1.405202
# 17     nlinear_smoothing     b                   3.564104         0.772049
#
#     Kullback-Leibler Divergence  Maximum Mean Discrepancy  \
# 0                      0.877295                  0.923422
# 1                      0.854490                  0.931151
# 2                      0.749632                  0.897766
# 3                      0.973748                  1.049428
# 4                      1.031221                  1.063073
# 5                      0.873227                  0.937027
# 6                      0.852159                  0.958787
# 7                      1.161319                  1.062278
# 8                      1.175377                  1.083785
# 9                      0.866145                  0.848655
# 10                     9.760249                  0.941576
# 11                    -5.333135                  1.149321
# 12                     0.994548                  0.917605
# 13                     1.308664                  0.943380
# 14                     1.423622                  1.854787
# 15                     0.394443                  0.341353
# 16                     1.237990                  1.480608
# 17                     0.551758                  0.658955
#
#     Wasserstein Distance  True Value
# 0               0.917275         1.0
# 1               0.949392         1.0
# 2               0.862380         1.0
# 3               1.074803         1.0
# 4               1.031428         1.0
# 5               1.006394         1.0
# 6               0.921750         1.0
# 7               1.076712         1.0
# 8               1.011055         1.0
# 9               0.894523         1.0
# 10              0.916855         1.0
# 11              1.219629         1.0
# 12              0.910704         1.0
# 13              0.971136         1.0
# 14              1.577404         1.0
# 15              0.602048         1.0
# 16              1.378130         1.0
# 17              0.787157         1.0

# %%
piv_table = pd.pivot_table(option1, values=["True Value", "Cramer-von Mises Distance", "Energy Distance", "Kullback-Leibler Divergence",
                                          "Maximum Mean Discrepancy", "Wasserstein Distance"], index = ["model", "param"])

piv_table = piv_table[["True Value", "Cramer-von Mises Distance", "Energy Distance", "Kullback-Leibler Divergence",
                       "Maximum Mean Discrepancy", "Wasserstein Distance"]]

piv_table
# Out:
#                             True Value  Cramer-von Mises Distance  \
# model                param
# n0.25_no_smoothing   a             1.0                   0.317941
#                      b             1.0                   2.873718
# n0.25_smoothing      a             1.0                   0.613641
#                      b             1.0                   1.562822
# n0.5_no_smoothing    a             1.0                   0.278493
#                      b             1.0                   3.028060
# n0.5_smoothing       a             1.0                   0.606495
#                      b             1.0                   2.601247
# n0.75_no_smoothing   a             1.0                   0.330620
#                      b             1.0                   3.735673
# n0.75_smoothing      a             1.0                   0.621965
#                      b             1.0                   1.528475
# n0_no_smoothing      a             1.0                   0.420432
#                      b             1.0                   3.165271
# nlinear_no_smoothing a             1.0                   0.161350
#                      b             1.0                   4.059528
# nlinear_smoothing    a             1.0                   0.135934
#                      b             1.0                   3.564104
#
#                             Energy Distance  Kullback-Leibler Divergence  \
# model                param
# n0.25_no_smoothing   a             0.924164                     0.877295
#                      b             0.939164                     0.854490
# n0.25_smoothing      a             0.910284                     0.749632
#                      b             1.060764                     0.973748
# n0.5_no_smoothing    a             1.060542                     1.031221
#                      b             0.999107                     0.873227
# n0.5_smoothing       a             0.965110                     0.852159
#                      b             1.068184                     1.161319
# n0.75_no_smoothing   a             1.007980                     1.175377
#                      b             0.875226                     0.866145
# n0.75_smoothing      a             0.957763                     9.760249
#                      b             1.165928                    -5.333135
# n0_no_smoothing      a             0.928897                     0.994548
#                      b             0.960640                     1.308664
# nlinear_no_smoothing a             1.624714                     1.423622
#                      b             0.596546                     0.394443
# nlinear_smoothing    a             1.405202                     1.237990
#                      b             0.772049                     0.551758
#
#                             Maximum Mean Discrepancy  Wasserstein Distance
# model                param
# n0.25_no_smoothing   a                      0.923422              0.917275
#                      b                      0.931151              0.949392
# n0.25_smoothing      a                      0.897766              0.862380
#                      b                      1.049428              1.074803
# n0.5_no_smoothing    a                      1.063073              1.031428
#                      b                      0.937027              1.006394
# n0.5_smoothing       a                      0.958787              0.921750
#                      b                      1.062278              1.076712
# n0.75_no_smoothing   a                      1.083785              1.011055
#                      b                      0.848655              0.894523
# n0.75_smoothing      a                      0.941576              0.916855
#                      b                      1.149321              1.219629
# n0_no_smoothing      a                      0.917605              0.910704
#                      b                      0.943380              0.971136
# nlinear_no_smoothing a                      1.854787              1.577404
#                      b                      0.341353              0.602048
# nlinear_smoothing    a                      1.480608              1.378130
#                      b                      0.658955              0.787157

# %%
df_styled = piv_table.style.background_gradient(axis=None, vmin=1, vmax=10, cmap="YlOrRd") #adding a gradient based on values in cell
df_styled.format(precision=2)
# Out:
# <style type="text/css">
# #T_2f890_row0_col0, #T_2f890_row0_col1, #T_2f890_row0_col2, #T_2f890_row0_col3, #T_2f890_row0_col4, #T_2f890_row0_col5, #T_2f890_row1_col0, #T_2f890_row1_col2, #T_2f890_row1_col3, #T_2f890_row1_col4, #T_2f890_row1_col5, #T_2f890_row2_col0, #T_2f890_row2_col1, #T_2f890_row2_col2, #T_2f890_row2_col3, #T_2f890_row2_col4, #T_2f890_row2_col5, #T_2f890_row3_col0, #T_2f890_row3_col3, #T_2f890_row4_col0, #T_2f890_row4_col1, #T_2f890_row4_col3, #T_2f890_row4_col5, #T_2f890_row5_col0, #T_2f890_row5_col2, #T_2f890_row5_col3, #T_2f890_row5_col4, #T_2f890_row5_col5, #T_2f890_row6_col0, #T_2f890_row6_col1, #T_2f890_row6_col2, #T_2f890_row6_col3, #T_2f890_row6_col4, #T_2f890_row6_col5, #T_2f890_row7_col0, #T_2f890_row8_col0, #T_2f890_row8_col1, #T_2f890_row8_col2, #T_2f890_row8_col5, #T_2f890_row9_col0, #T_2f890_row9_col2, #T_2f890_row9_col3, #T_2f890_row9_col4, #T_2f890_row9_col5, #T_2f890_row10_col0, #T_2f890_row10_col1, #T_2f890_row10_col2, #T_2f890_row10_col4, #T_2f890_row10_col5, #T_2f890_row11_col0, #T_2f890_row11_col3, #T_2f890_row12_col0, #T_2f890_row12_col1, #T_2f890_row12_col2, #T_2f890_row12_col3, #T_2f890_row12_col4, #T_2f890_row12_col5, #T_2f890_row13_col0, #T_2f890_row13_col2, #T_2f890_row13_col4, #T_2f890_row13_col5, #T_2f890_row14_col0, #T_2f890_row14_col1, #T_2f890_row15_col0, #T_2f890_row15_col2, #T_2f890_row15_col3, #T_2f890_row15_col4, #T_2f890_row15_col5, #T_2f890_row16_col0, #T_2f890_row16_col1, #T_2f890_row17_col0, #T_2f890_row17_col2, #T_2f890_row17_col3, #T_2f890_row17_col4, #T_2f890_row17_col5 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_2f890_row1_col1 {
#   background-color: #fee084;
#   color: #000000;
# }
# #T_2f890_row3_col1, #T_2f890_row14_col5 {
#   background-color: #fff6b6;
#   color: #000000;
# }
# #T_2f890_row3_col2, #T_2f890_row3_col4, #T_2f890_row4_col2, #T_2f890_row4_col4, #T_2f890_row7_col2, #T_2f890_row7_col4 {
#   background-color: #fffecb;
#   color: #000000;
# }
# #T_2f890_row3_col5, #T_2f890_row7_col5, #T_2f890_row8_col4 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_2f890_row5_col1 {
#   background-color: #fedd7f;
#   color: #000000;
# }
# #T_2f890_row7_col1 {
#   background-color: #ffe58f;
#   color: #000000;
# }
# #T_2f890_row7_col3, #T_2f890_row8_col3, #T_2f890_row11_col2, #T_2f890_row11_col4 {
#   background-color: #fffdc6;
#   color: #000000;
# }
# #T_2f890_row9_col1 {
#   background-color: #fec965;
#   color: #000000;
# }
# #T_2f890_row10_col3 {
#   background-color: #8b0026;
#   color: #f1f1f1;
# }
# #T_2f890_row11_col1 {
#   background-color: #fff7b7;
#   color: #000000;
# }
# #T_2f890_row11_col5, #T_2f890_row16_col3 {
#   background-color: #fffcc4;
#   color: #000000;
# }
# #T_2f890_row13_col1 {
#   background-color: #fedb7a;
#   color: #000000;
# }
# #T_2f890_row13_col3 {
#   background-color: #fffac1;
#   color: #000000;
# }
# #T_2f890_row14_col2 {
#   background-color: #fff5b5;
#   color: #000000;
# }
# #T_2f890_row14_col3 {
#   background-color: #fff8bb;
#   color: #000000;
# }
# #T_2f890_row14_col4 {
#   background-color: #fff1ab;
#   color: #000000;
# }
# #T_2f890_row15_col1 {
#   background-color: #febd57;
#   color: #000000;
# }
# #T_2f890_row16_col2 {
#   background-color: #fff9bd;
#   color: #000000;
# }
# #T_2f890_row16_col4 {
#   background-color: #fff8ba;
#   color: #000000;
# }
# #T_2f890_row16_col5 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_2f890_row17_col1 {
#   background-color: #fecf6b;
#   color: #000000;
# }
# </style>
# <table id="T_2f890">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f890_level0_col0" class="col_heading level0 col0" >True Value</th>
#       <th id="T_2f890_level0_col1" class="col_heading level0 col1" >Cramer-von Mises Distance</th>
#       <th id="T_2f890_level0_col2" class="col_heading level0 col2" >Energy Distance</th>
#       <th id="T_2f890_level0_col3" class="col_heading level0 col3" >Kullback-Leibler Divergence</th>
#       <th id="T_2f890_level0_col4" class="col_heading level0 col4" >Maximum Mean Discrepancy</th>
#       <th id="T_2f890_level0_col5" class="col_heading level0 col5" >Wasserstein Distance</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >param</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f890_level0_row0" class="row_heading level0 row0" rowspan="2">n0.25_no_smoothing</th>
#       <th id="T_2f890_level1_row0" class="row_heading level1 row0" >a</th>
#       <td id="T_2f890_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_2f890_row0_col1" class="data row0 col1" >0.32</td>
#       <td id="T_2f890_row0_col2" class="data row0 col2" >0.92</td>
#       <td id="T_2f890_row0_col3" class="data row0 col3" >0.88</td>
#       <td id="T_2f890_row0_col4" class="data row0 col4" >0.92</td>
#       <td id="T_2f890_row0_col5" class="data row0 col5" >0.92</td>
#     </tr>
#     <tr>
#       <th id="T_2f890_level1_row1" class="row_heading level1 row1" >b</th>
#       <td id="T_2f890_row1_col0" class="data row1 col0" >1.00</td>
#       <td id="T_2f890_row1_col1" class="data row1 col1" >2.87</td>
#       <td id="T_2f890_row1_col2" class="data row1 col2" >0.94</td>
#       <td id="T_2f890_row1_col3" class="data row1 col3" >0.85</td>
#       <td id="T_2f890_row1_col4" class="data row1 col4" >0.93</td>
#       <td id="T_2f890_row1_col5" class="data row1 col5" >0.95</td>
#     </tr>
#     <tr>
#       <th id="T_2f890_level0_row2" class="row_heading level0 row2" rowspan="2">n0.25_smoothing</th>
#       <th id="T_2f890_level1_row2" class="row_heading level1 row2" >a</th>
#       <td id="T_2f890_row2_col0" class="data row2 col0" >1.00</td>
#       <td id="T_2f890_row2_col1" class="data row2 col1" >0.61</td>
#       <td id="T_2f890_row2_col2" class="data row2 col2" >0.91</td>
#       <td id="T_2f890_row2_col3" class="data row2 col3" >0.75</td>
#       <td id="T_2f890_row2_col4" class="data row2 col4" >0.90</td>
#       <td id="T_2f890_row2_col5" class="data row2 col5" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_2f890_level1_row3" class="row_heading level1 row3" >b</th>
#       <td id="T_2f890_row3_col0" class="data row3 col0" >1.00</td>
#       <td id="T_2f890_row3_col1" class="data row3 col1" >1.56</td>
#       <td id="T_2f890_row3_col2" class="data row3 col2" >1.06</td>
#       <td id="T_2f890_row3_col3" class="data row3 col3" >0.97</td>
#       <td id="T_2f890_row3_col4" class="data row3 col4" >1.05</td>
#       <td id="T_2f890_row3_col5" class="data row3 col5" >1.07</td>
#     </tr>
#     <tr>
#       <th id="T_2f890_level0_row4" class="row_heading level0 row4" rowspan="2">n0.5_no_smoothing</th>
#       <th id="T_2f890_level1_row4" class="row_heading level1 row4" >a</th>
#       <td id="T_2f890_row4_col0" class="data row4 col0" >1.00</td>
#       <td id="T_2f890_row4_col1" class="data row4 col1" >0.28</td>
#       <td id="T_2f890_row4_col2" class="data row4 col2" >1.06</td>
#       <td id="T_2f890_row4_col3" class="data row4 col3" >1.03</td>
#       <td id="T_2f890_row4_col4" class="data row4 col4" >1.06</td>
#       <td id="T_2f890_row4_col5" class="data row4 col5" >1.03</td>
#     </tr>
#     <tr>
#       <th id="T_2f890_level1_row5" class="row_heading level1 row5" >b</th>
#       <td id="T_2f890_row5_col0" class="data row5 col0" >1.00</td>
#       <td id="T_2f890_row5_col1" class="data row5 col1" >3.03</td>
#       <td id="T_2f890_row5_col2" class="data row5 col2" >1.00</td>
#       <td id="T_2f890_row5_col3" class="data row5 col3" >0.87</td>
#       <td id="T_2f890_row5_col4" class="data row5 col4" >0.94</td>
#       <td id="T_2f890_row5_col5" class="data row5 col5" >1.01</td>
#     </tr>
#     <tr>
#       <th id="T_2f890_level0_row6" class="row_heading level0 row6" rowspan="2">n0.5_smoothing</th>
#       <th id="T_2f890_level1_row6" class="row_heading level1 row6" >a</th>
#       <td id="T_2f890_row6_col0" class="data row6 col0" >1.00</td>
#       <td id="T_2f890_row6_col1" class="data

# %%
dfi.export(df_styled,"test.png")

# %% [markdown]
# # Option 2 - Columns are Difference between True and Simulated Value

# %%
option2 = median_table.copy()
s = median_table.select_dtypes("number").columns
option2[s] = np.round(np.abs(median_table[s]-1), 3)

# %%
piv_table_2 = pd.pivot_table(option2, values=["Cramer-von Mises Distance", "Energy Distance", "Kullback-Leibler Divergence",
                                          "Maximum Mean Discrepancy", "Wasserstein Distance"], index = ["model", "param"])

piv_table_2 = piv_table_2[["Cramer-von Mises Distance", "Energy Distance", "Kullback-Leibler Divergence",
                       "Maximum Mean Discrepancy", "Wasserstein Distance"]]

piv_table_2
# Out:
#                          Cramer-von Mises Distance  Energy Distance  \
# model             param
# n0.5_no_smoothing a                          1.246            0.042
#                   b                          2.446            0.230
# n0.5_smoothing    a                          4.410            0.007
#                   b                          5.322            0.040
# n0_no_smoothing   a                          1.056            0.058
#                   b                          1.993            0.083
#
#                          Kullback-Leibler Divergence  \
# model             param
# n0.5_no_smoothing a                            0.078
#                   b                            1.823
# n0.5_smoothing    a                            0.452
#                   b                            1.917
# n0_no_smoothing   a                            0.275
#                   b                            1.785
#
#                          Maximum Mean Discrepancy  Wasserstein Distance
# model             param
# n0.5_no_smoothing a                         0.042                 0.123
#                   b                         0.230                 0.168
# n0.5_smoothing    a                         0.007                 0.170
#                   b                         0.040                 0.750
# n0_no_smoothing   a                         0.085                 0.138
#                   b                         0.051                 0.543

# %%
df_styled_2 = piv_table_2.style.background_gradient(axis=None, vmin=0, vmax=10, cmap="YlGnBu") #adding a gradient based on values in cell
df_styled_2.format(precision=2)
# Out:
# <style type="text/css">
# #T_08068_row0_col0 {
#   background-color: #edf8b2;
#   color: #000000;
# }
# #T_08068_row0_col1, #T_08068_row0_col2, #T_08068_row0_col3, #T_08068_row3_col1, #T_08068_row3_col3, #T_08068_row4_col1, #T_08068_row5_col3 {
#   background-color: #feffd8;
#   color: #000000;
# }
# #T_08068_row0_col4, #T_08068_row4_col4 {
#   background-color: #fdfed5;
#   color: #000000;
# }
# #T_08068_row1_col0 {
#   background-color: #c9eab4;
#   color: #000000;
# }
# #T_08068_row1_col1, #T_08068_row1_col3 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_08068_row1_col2 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_08068_row1_col4, #T_08068_row2_col4 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_08068_row2_col0 {
#   background-color: #5fc1c0;
#   color: #000000;
# }
# #T_08068_row2_col1, #T_08068_row2_col3 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_08068_row2_col2 {
#   background-color: #f9fdcb;
#   color: #000000;
# }
# #T_08068_row3_col0 {
#   background-color: #37acc3;
#   color: #f1f1f1;
# }
# #T_08068_row3_col2 {
#   background-color: #d9f0b3;
#   color: #000000;
# }
# #T_08068_row3_col4 {
#   background-color: #f4fbc1;
#   color: #000000;
# }
# #T_08068_row4_col0 {
#   background-color: #f0f9b7;
#   color: #000000;
# }
# #T_08068_row4_col2 {
#   background-color: #fbfdd0;
#   color: #000000;
# }
# #T_08068_row4_col3, #T_08068_row5_col1 {
#   background-color: #feffd6;
#   color: #000000;
# }
# #T_08068_row5_col0 {
#   background-color: #d6efb3;
#   color: #000000;
# }
# #T_08068_row5_col2 {
#   background-color: #ddf2b2;
#   color: #000000;
# }
# #T_08068_row5_col4 {
#   background-color: #f8fcc9;
#   color: #000000;
# }
# </style>
# <table id="T_08068">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08068_level0_col0" class="col_heading level0 col0" >Cramer-von Mises Distance</th>
#       <th id="T_08068_level0_col1" class="col_heading level0 col1" >Energy Distance</th>
#       <th id="T_08068_level0_col2" class="col_heading level0 col2" >Kullback-Leibler Divergence</th>
#       <th id="T_08068_level0_col3" class="col_heading level0 col3" >Maximum Mean Discrepancy</th>
#       <th id="T_08068_level0_col4" class="col_heading level0 col4" >Wasserstein Distance</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >param</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08068_level0_row0" class="row_heading level0 row0" rowspan="2">n0.5_no_smoothing</th>
#       <th id="T_08068_level1_row0" class="row_heading level1 row0" >a</th>
#       <td id="T_08068_row0_col0" class="data row0 col0" >1.25</td>
#       <td id="T_08068_row0_col1" class="data row0 col1" >0.04</td>
#       <td id="T_08068_row0_col2" class="data row0 col2" >0.08</td>
#       <td id="T_08068_row0_col3" class="data row0 col3" >0.04</td>
#       <td id="T_08068_row0_col4" class="data row0 col4" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_08068_level1_row1" class="row_heading level1 row1" >b</th>
#       <td id="T_08068_row1_col0" class="data row1 col0" >2.45</td>
#       <td id="T_08068_row1_col1" class="data row1 col1" >0.23</td>
#       <td id="T_08068_row1_col2" class="data row1 col2" >1.82</td>
#       <td id="T_08068_row1_col3" class="data row1 col3" >0.23</td>
#       <td id="T_08068_row1_col4" class="data row1 col4" >0.17</td>
#     </tr>
#     <tr>
#       <th id="T_08068_level0_row2" class="row_heading level0 row2" rowspan="2">n0.5_smoothing</th>
#       <th id="T_08068_level1_row2" class="row_heading level1 row2" >a</th>
#       <td id="T_08068_row2_col0" class="data row2 col0" >4.41</td>
#       <td id="T_08068_row2_col1" class="data row2 col1" >0.01</td>
#       <td id="T_08068_row2_col2" class="data row2 col2" >0.45</td>
#       <td id="T_08068_row2_col3" class="data row2 col3" >0.01</td>
#       <td id="T_08068_row2_col4" class="data row2 col4" >0.17</td>
#     </tr>
#     <tr>
#       <th id="T_08068_level1_row3" class="row_heading level1 row3" >b</th>
#       <td id="T_08068_row3_col0" class="data row3 col0" >5.32</td>
#       <td id="T_08068_row3_col1" class="data row3 col1" >0.04</td>
#       <td id="T_08068_row3_col2" class="data row3 col2" >1.92</td>
#       <td id="T_08068_row3_col3" class="data row3 col3" >0.04</td>
#       <td id="T_08068_row3_col4" class="data row3 col4" >0.75</td>
#     </tr>
#     <tr>
#       <th id="T_08068_level0_row4" class="row_heading level0 row4" rowspan="2">n0_no_smoothing</th>
#       <th id="T_08068_level1_row4" class="row_heading level1 row4" >a</th>
#       <td id="T_08068_row4_col0" class="data row4 col0" >1.06</td>
#       <td id="T_08068_row4_col1" class="data row4 col1" >0.06</td>
#       <td id="T_08068_row4_col2" class="data row4 col2" >0.28</td>
#       <td id="T_08068_row4_col3" class="data row4 col3" >0.09</td>
#       <td id="T_08068_row4_col4" class="data row4 col4" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_08068_level1_row5" class="row_heading level1 row5" >b</th>
#       <td id="T_08068_row5_col0" class="data row5 col0" >1.99</td>
#       <td id="T_08068_row5_col1" class="data row5 col1" >0.08</td>
#       <td id="T_08068_row5_col2" class="data row5 col2" >1.78</td>
#       <td id="T_08068_row5_col3" class="data row5 col3" >0.05</td>
#       <td id="T_08068_row5_col4" class="data row5 col4" >0.54</td>
#     </tr>
#   </tbody>
# </table>

# %%
dfi.export(df_styled_2,"test_2.png")

# %% [markdown]
# # Table for RMSE

# %%
rmse = df[(df["summary_statistic"] == "RMSE") & (df["quantile"] == "0.1%")].reset_index(drop=True)
rmse = rmse[keep_cols]
rmse
# Out:
#                    model param  Cramer-von Mises Distance  Energy Distance  \
# 0     n0.25_no_smoothing     a                   0.682068         0.076266
# 1     n0.25_no_smoothing     b                   1.873852         0.061386
# 2        n0.25_smoothing     a                   0.386427         0.090082
# 3        n0.25_smoothing     b                   0.562993         0.061562
# 4      n0.5_no_smoothing     a                   0.721528         0.061297
# 5      n0.5_no_smoothing     b                   2.028183         0.009305
# 6         n0.5_smoothing     a                   0.393526         0.035716
# 7         n0.5_smoothing     b                   1.601445         0.069099
# 8     n0.75_no_smoothing     a                   0.669389         0.012280
# 9     n0.75_no_smoothing     b                   2.735820         0.125062
# 10       n0.75_smoothing     a                   0.378119         0.042746
# 11       n0.75_smoothing     b                   0.528593         0.166284
# 12       n0_no_smoothing     a                   0.579583         0.071627
# 13       n0_no_smoothing     b                   2.165370         0.040494
# 14  nlinear_no_smoothing     a                   0.838735         0.624829
# 15  nlinear_no_smoothing     b                   3.059805         0.403502
# 16     nlinear_smoothing     a                   0.864069         0.405336
# 17     nlinear_smoothing     b                   2.564437         0.228088
#
#     Kullback-Leibler Divergence  Maximum Mean Discrepancy  \
# 0                      0.123420                  0.077011
# 1                      0.146211                  0.069373
# 2                      0.250706                  0.102575
# 3                      0.031700                  0.050374
# 4                      0.033440                  0.063864
# 5                      0.127460                  0.063732
# 6                      0.147967                  0.041930
# 7                      0.162216                  0.063236
# 8                      0.175727                  0.084511
# 9                      0.134650                  0.151623
# 10                     8.760255                  0.058812
# 11                     6.333165                  0.149733
# 12                     0.013648                  0.082817
# 13                     0.308975                  0.057358
# 14                     0.424973                  0.854903
# 15                     0.605630                  0.658701
# 16                     0.238412                  0.480693
# 17                     0.448357                  0.341193
#
#     Wasserstein Distance
# 0               0.083051
# 1               0.051449
# 2               0.137817
# 3               0.075506
# 4               0.032542
# 5               0.011515
# 6               0.078523
# 7               0.077657
# 8               0.013587
# 9               0.105942
# 10              0.083303
# 11              0.220040
# 12              0.089600
# 13              0.030755
# 14              0.577582
# 15              0.398002
# 16              0.378259
# 17              0.213010

# %%
rmse_table = pd.pivot_table(rmse, values=["Cramer-von Mises Distance", "Energy Distance", "Kullback-Leibler Divergence",
                                          "Maximum Mean Discrepancy", "Wasserstein Distance"], index = ["model", "param"])

rmse_table
# Out:
#                             Cramer-von Mises Distance  Energy Distance  \
# model                param
# n0.25_no_smoothing   a                       0.682068         0.076266
#                      b                       1.873852         0.061386
# n0.25_smoothing      a                       0.386427         0.090082
#                      b                       0.562993         0.061562
# n0.5_no_smoothing    a                       0.721528         0.061297
#                      b                       2.028183         0.009305
# n0.5_smoothing       a                       0.393526         0.035716
#                      b                       1.601445         0.069099
# n0.75_no_smoothing   a                       0.669389         0.012280
#                      b                       2.735820         0.125062
# n0.75_smoothing      a                       0.378119         0.042746
#                      b                       0.528593         0.166284
# n0_no_smoothing      a                       0.579583         0.071627
#                      b                       2.165370         0.040494
# nlinear_no_smoothing a                       0.838735         0.624829
#                      b                       3.059805         0.403502
# nlinear_smoothing    a                       0.864069         0.405336
#                      b                       2.564437         0.228088
#
#                             Kullback-Leibler Divergence  \
# model                param
# n0.25_no_smoothing   a                         0.123420
#                      b                         0.146211
# n0.25_smoothing      a                         0.250706
#                      b                         0.031700
# n0.5_no_smoothing    a                         0.033440
#                      b                         0.127460
# n0.5_smoothing       a                         0.147967
#                      b                         0.162216
# n0.75_no_smoothing   a                         0.175727
#                      b                         0.134650
# n0.75_smoothing      a                         8.760255
#                      b                         6.333165
# n0_no_smoothing      a                         0.013648
#                      b                         0.308975
# nlinear_no_smoothing a                         0.424973
#                      b                         0.605630
# nlinear_smoothing    a                         0.238412
#                      b                         0.448357
#
#                             Maximum Mean Discrepancy  Wasserstein Distance
# model                param
# n0.25_no_smoothing   a                      0.077011              0.083051
#                      b                      0.069373              0.051449
# n0.25_smoothing      a                      0.102575              0.137817
#                      b                      0.050374              0.075506
# n0.5_no_smoothing    a                      0.063864              0.032542
#                      b                      0.063732              0.011515
# n0.5_smoothing       a                      0.041930              0.078523
#                      b                      0.063236              0.077657
# n0.75_no_smoothing   a                      0.084511              0.013587
#                      b                      0.151623              0.105942
# n0.75_smoothing      a                      0.058812              0.083303
#                      b                      0.149733              0.220040
# n0_no_smoothing      a                      0.082817              0.089600
#                      b                      0.057358              0.030755
# nlinear_no_smoothing a                      0.854903              0.577582
#                      b                      0.658701              0.398002
# nlinear_smoothing    a                      0.480693              0.378259
#                      b                      0.341193              0.213010

# %%
rmse_styled = rmse_table.style.background_gradient(axis=None, vmin=0, vmax=10, cmap="YlOrRd") #adding a gradient based on values in cell
rmse_styled.format(precision=2)
# Out:
# <style type="text/css">
# #T_b3e4b_row0_col0, #T_b3e4b_row8_col0 {
#   background-color: #fff5b5;
#   color: #000000;
# }
# #T_b3e4b_row0_col1, #T_b3e4b_row0_col3, #T_b3e4b_row1_col1, #T_b3e4b_row1_col3, #T_b3e4b_row1_col4, #T_b3e4b_row3_col1, #T_b3e4b_row3_col3, #T_b3e4b_row3_col4, #T_b3e4b_row4_col1, #T_b3e4b_row4_col3, #T_b3e4b_row5_col3, #T_b3e4b_row6_col3, #T_b3e4b_row7_col1, #T_b3e4b_row7_col3, #T_b3e4b_row7_col4, #T_b3e4b_row10_col1, #T_b3e4b_row10_col3, #T_b3e4b_row12_col1, #T_b3e4b_row13_col1, #T_b3e4b_row13_col3 {
#   background-color: #fffecb;
#   color: #000000;
# }
# #T_b3e4b_row0_col2, #T_b3e4b_row1_col2, #T_b3e4b_row2_col4, #T_b3e4b_row5_col2, #T_b3e4b_row6_col2, #T_b3e4b_row9_col1, #T_b3e4b_row9_col2, #T_b3e4b_row9_col3, #T_b3e4b_row11_col3 {
#   background-color: #fffdc8;
#   color: #000000;
# }
# #T_b3e4b_row0_col4, #T_b3e4b_row2_col1, #T_b3e4b_row2_col3, #T_b3e4b_row6_col4, #T_b3e4b_row8_col3, #T_b3e4b_row9_col4, #T_b3e4b_row10_col4, #T_b3e4b_row12_col3, #T_b3e4b_row12_col4 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_b3e4b_row1_col0 {
#   background-color: #ffe48c;
#   color: #000000;
# }
# #T_b3e4b_row2_col0, #T_b3e4b_row10_col0, #T_b3e4b_row16_col4 {
#   background-color: #fffac0;
#   color: #000000;
# }
# #T_b3e4b_row2_col2, #T_b3e4b_row16_col2 {
#   background-color: #fffcc4;
#   color: #000000;
# }
# #T_b3e4b_row3_col0, #T_b3e4b_row12_col0, #T_b3e4b_row14_col4 {
#   background-color: #fff7b9;
#   color: #000000;
# }
# #T_b3e4b_row3_col2, #T_b3e4b_row4_col2, #T_b3e4b_row4_col4, #T_b3e4b_row5_col1, #T_b3e4b_row5_col4, #T_b3e4b_row6_col1, #T_b3e4b_row8_col1, #T_b3e4b_row8_col4, #T_b3e4b_row12_col2, #T_b3e4b_row13_col4 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_b3e4b_row4_col0 {
#   background-color: #fff5b3;
#   color: #000000;
# }
# #T_b3e4b_row5_col0 {
#   background-color: #fee187;
#   color: #000000;
# }
# #T_b3e4b_row6_col0, #T_b3e4b_row14_col2, #T_b3e4b_row15_col1, #T_b3e4b_row15_col4, #T_b3e4b_row16_col1 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_b3e4b_row7_col0 {
#   background-color: #ffe895;
#   color: #000000;
# }
# #T_b3e4b_row7_col2, #T_b3e4b_row8_col2, #T_b3e4b_row11_col1 {
#   background-color: #fffdc6;
#   color: #000000;
# }
# #T_b3e4b_row9_col0 {
#   background-color: #fed16e;
#   color: #000000;
# }
# #T_b3e4b_row10_col2 {
#   background-color: #bb0026;
#   color: #f1f1f1;
# }
# #T_b3e4b_row11_col0 {
#   background-color: #fff8ba;
#   color: #000000;
# }
# #T_b3e4b_row11_col2 {
#   background-color: #fa4a29;
#   color: #f1f1f1;
# }
# #T_b3e4b_row11_col4, #T_b3e4b_row17_col1, #T_b3e4b_row17_col4 {
#   background-color: #fffcc5;
#   color: #000000;
# }
# #T_b3e4b_row13_col0 {
#   background-color: #fede82;
#   color: #000000;
# }
# #T_b3e4b_row13_col2 {
#   background-color: #fffbc2;
#   color: #000000;
# }
# #T_b3e4b_row14_col0, #T_b3e4b_row14_col3 {
#   background-color: #fff3af;
#   color: #000000;
# }
# #T_b3e4b_row14_col1, #T_b3e4b_row15_col2 {
#   background-color: #fff7b7;
#   color: #000000;
# }
# #T_b3e4b_row15_col0 {
#   background-color: #fec863;
#   color: #000000;
# }
# #T_b3e4b_row15_col3 {
#   background-color: #fff6b6;
#   color: #000000;
# }
# #T_b3e4b_row16_col0 {
#   background-color: #fff3ae;
#   color: #000000;
# }
# #T_b3e4b_row16_col3 {
#   background-color: #fff8bb;
#   color: #000000;
# }
# #T_b3e4b_row17_col0 {
#   background-color: #fed774;
#   color: #000000;
# }
# #T_b3e4b_row17_col2 {
#   background-color: #fff9bd;
#   color: #000000;
# }
# #T_b3e4b_row17_col3 {
#   background-color: #fffac1;
#   color: #000000;
# }
# </style>
# <table id="T_b3e4b">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3e4b_level0_col0" class="col_heading level0 col0" >Cramer-von Mises Distance</th>
#       <th id="T_b3e4b_level0_col1" class="col_heading level0 col1" >Energy Distance</th>
#       <th id="T_b3e4b_level0_col2" class="col_heading level0 col2" >Kullback-Leibler Divergence</th>
#       <th id="T_b3e4b_level0_col3" class="col_heading level0 col3" >Maximum Mean Discrepancy</th>
#       <th id="T_b3e4b_level0_col4" class="col_heading level0 col4" >Wasserstein Distance</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >param</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3e4b_level0_row0" class="row_heading level0 row0" rowspan="2">n0.25_no_smoothing</th>
#       <th id="T_b3e4b_level1_row0" class="row_heading level1 row0" >a</th>
#       <td id="T_b3e4b_row0_col0" class="data row0 col0" >0.68</td>
#       <td id="T_b3e4b_row0_col1" class="data row0 col1" >0.08</td>
#       <td id="T_b3e4b_row0_col2" class="data row0 col2" >0.12</td>
#       <td id="T_b3e4b_row0_col3" class="data row0 col3" >0.08</td>
#       <td id="T_b3e4b_row0_col4" class="data row0 col4" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_b3e4b_level1_row1" class="row_heading level1 row1" >b</th>
#       <td id="T_b3e4b_row1_col0" class="data row1 col0" >1.87</td>
#       <td id="T_b3e4b_row1_col1" class="data row1 col1" >0.06</td>
#       <td id="T_b3e4b_row1_col2" class="data row1 col2" >0.15</td>
#       <td id="T_b3e4b_row1_col3" class="data row1 col3" >0.07</td>
#       <td id="T_b3e4b_row1_col4" class="data row1 col4" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_b3e4b_level0_row2" class="row_heading level0 row2" rowspan="2">n0.25_smoothing</th>
#       <th id="T_b3e4b_level1_row2" class="row_heading level1 row2" >a</th>
#       <td id="T_b3e4b_row2_col0" class="data row2 col0" >0.39</td>
#       <td id="T_b3e4b_row2_col1" class="data row2 col1" >0.09</td>
#       <td id="T_b3e4b_row2_col2" class="data row2 col2" >0.25</td>
#       <td id="T_b3e4b_row2_col3" class="data row2 col3" >0.10</td>
#       <td id="T_b3e4b_row2_col4" class="data row2 col4" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_b3e4b_level1_row3" class="row_heading level1 row3" >b</th>
#       <td id="T_b3e4b_row3_col0" class="data row3 col0" >0.56</td>
#       <td id="T_b3e4b_row3_col1" class="data row3 col1" >0.06</td>
#       <td id="T_b3e4b_row3_col2" class="data row3 col2" >0.03</td>
#       <td id="T_b3e4b_row3_col3" class="data row3 col3" >0.05</td>
#       <td id="T_b3e4b_row3_col4" class="data row3 col4" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_b3e4b_level0_row4" class="row_heading level0 row4" rowspan="2">n0.5_no_smoothing</th>
#       <th id="T_b3e4b_level1_row4" class="row_heading level1 row4" >a</th>
#       <td id="T_b3e4b_row4_col0" class="data row4 col0" >0.72</td>
#       <td id="T_b3e4b_row4_col1" class="data row4 col1" >0.06</td>
#       <td id="T_b3e4b_row4_col2" class="data row4 col2" >0.03</td>
#       <td id="T_b3e4b_row4_col3" class="data row4 col3" >0.06</td>
#       <td id="T_b3e4b_row4_col4" class="data row4 col4" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_b3e4b_level1_row5" class="row_heading level1 row5" >b</th>
#       <td id="T_b3e4b_row5_col0" class="data row5 col0" >2.03</td>
#       <td id="T_b3e4b_row5_col1" class="data row5 col1" >0.01</td>
#       <td id="T_b3e4b_row5_col2" class="data row5 col2" >0.13</td>
#       <td id="T_b3e4b_row5_col3" class="data row5 col3" >0.06</td>
#       <td id="T_b3e4b_row5_col4" class="data row5 col4" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_b3e4b_level0_row6" class="row_heading level0 row6" rowspan="2">n0.5_smoothing</th>
#       <th id="T_b3e4b_level1_row6" class="row_heading level1 row6" >a</th>
#       <td id="T_b3e4b_row6_col0" class="data row6 col0" >0.39</td>
#       <td id="T_b3e4b_row6_col1" class="data row6 col1" >0.04</td>
#       <td id="T_b3e4b_row6_col2" class="data row6 col2" >0.15</td>
#       <td id="T_b3e4b_row6_col3" class="data row6 col3" >0.04</td>
#       <td id="T_b3e4b_row6_col4" class="data row6 col4" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_b3e4b_level1_row7" class="row_heading level1 row7" >b</th>
#       <td id="T_b3e4b_row7_col0" class="data row7 col0" >1.60</td>
#       <td id="T_b3e4b_row7_col1" class="data row7 col1" >0.07</td>
#       <td id="T_b3e4b_row7_col2" class="data

# %%
dfi.export(rmse_styled,"test_rmse.png")

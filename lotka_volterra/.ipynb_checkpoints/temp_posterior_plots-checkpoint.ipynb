# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
current_path = os.getcwd()
models_path = os.path.join(current_path, "results")
models = os.listdir(models_path)
metric_path = os.path.join(models_path, models[0])
metrics = os.listdir(metric_path)

# %%
fig, ax = plt.subplots(2, 3, sharex=True, sharey=True)
ax = ax.flatten()
for idx, model in enumerate(models):
    for metric in metrics:
        # Want all metrics in one plot
        posterior_path = os.path.join(metric_path, metric)
        posteriors = os.listdir(posterior_path)
        # We only want the 0.1% quantiles - but we use 5% just because there is more samples atm
        path = os.path.join(posterior_path, posteriors[2])
        p = np.load(path)
        # Want median values only
        print(p[:,:,1][:,0])
# Out:
# [7.22835638 6.70982552 7.62327301 6.75686925 7.05426039]
# [1.23090405 1.12012397 1.12614357 0.91550362 1.21521777]
# [1.53545462 1.41823674 1.23439318 1.00795092 1.39249002]
# [2.58320854 2.19586346 2.47215135 1.83499971 2.19141502]
# [-0.06754339  0.08021423 -0.10232316 -0.00659435 -0.24065466]
# [7.22835638 6.70982552 7.62327301 6.75686925 7.05426039]
# [1.23090405 1.12012397 1.12614357 0.91550362 1.21521777]
# [1.53545462 1.41823674 1.23439318 1.00795092 1.39249002]
# [2.58320854 2.19586346 2.47215135 1.83499971 2.19141502]
# [-0.06754339  0.08021423 -0.10232316 -0.00659435 -0.24065466]
# [7.22835638 6.70982552 7.62327301 6.75686925 7.05426039]
# [1.23090405 1.12012397 1.12614357 0.91550362 1.21521777]
# [1.53545462 1.41823674 1.23439318 1.00795092 1.39249002]
# [2.58320854 2.19586346 2.47215135 1.83499971 2.19141502]
# [-0.06754339  0.08021423 -0.10232316 -0.00659435 -0.24065466]
